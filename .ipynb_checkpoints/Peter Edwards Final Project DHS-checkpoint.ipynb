# %%
import sqlite3
import pandas as pd
import sqlalchemy
import matplotlib
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
#import stata_setup
#stata_setup.config("C:/Program Files/Stata17/", "se")

# %%
#!pip install --upgrade --user stata_setup
import stata_setup
stata_setup.__version__
# Out:
# '0.1.2'

# %%
from pystata import stata

# %%
clev_df = pd.read_csv('cleveland.heart.csv')
cal_df = pd.read_csv('california.heart.csv')
hung_df = pd.read_csv('hungary.heart.csv')
switz_df = pd.read_csv('switzerland.heart.csv')

# %%
clev_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca  thal  num
# 0        3  0.0   6.0    0
# 1        2  3.0   3.0    2
# 2        2  2.0   7.0    1
# 3        3  0.0   3.0    0
# 4        1  0.0   3.0    0
# ..     ...  ...   ...  ...
# 298      2  0.0   7.0    1
# 299      2  2.0   7.0    2
# 300      2  1.0   7.0    3
# 301      2  1.0   3.0    1
# 302      1  NaN   3.0    0
#
# [303 rows x 14 columns]

# %%
pd.options.display.float_format = "{:,.0f}".format
cal_df['loc'] = 1
clev_df['loc'] = 2
hung_df['loc'] = 3
switz_df['loc'] = 4
#1 California
#2 Cleveland
#3 Hungary
#4 Switzerland
clev_df.describe()
# Out:
#        age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# count  303  303 303       303   303  303      303      303    303      303
# mean    54    1   3       132   247    0        1      150      0        1
# std      9    0   1        18    52    0        1       23      0        1
# min     29    0   1        94   126    0        0       71      0        0
# 25%     48    0   3       120   211    0        0      134      0        0
# 50%     56    1   3       130   241    0        1      153      0        1
# 75%     61    1   4       140   275    0        2      166      1        2
# max     77    1   4       200   564    1        2      202      1        6
#
#        slope  ca  thal  num  loc
# count    303 299   301  303  303
# mean       2   1     5    1    2
# std        1   1     2    1    0
# min        1   0     3    0    2
# 25%        1   0     3    0    2
# 50%        2   0     3    0    2
# 75%        2   1     7    2    2
# max        3   3     7    4    2

# %% [raw]
#  -- Only 14 used
#       -- 1. #3  (age)          age: age in years
#       -- 2. #4  (sex)          sex: sex (1 = male; 0 = female)
#       -- 3. #9  (cp)           cp: chest pain type (1=typical angina,  2=atypical angina, 3=non-anginal pain  4=asymptomatic
#       -- 4. #10 (trestbps)     resting blood pressure (in mm Hg on admission to the hospital) ???systolic
#       -- 5. #12 (chol)         chol: serum cholestoral in mg/dl
#       -- 6. #16 (fbs)          (fasting blood sugar > 120 mg/dl)  (1 = true; 0 = false)
#       -- 7. #19 (restecg)   restecg: resting electrocardiographic results
#                             -- Value 0: normal
#                                 -- Value 1: having ST-T wave abnormality (T wave inversions and/or ST
#                                     elevation or depression of > 0.05 mV)
#                             -- Value 2: showing probable or definite left ventricular hypertrophy
#                                 by Estes' criteria
#       -- 8. #32 (thalach)   thalach: maximum heart rate achieved
#       -- 9. #38 (exang)     exang: exercise induced angina (1 = yes; 0 = no)
#       -- 10. #40 (oldpeak)   oldpeak = ST depression induced by exercise relative to rest
#       -- 11. #41 (slope)     slope: the slope of the peak exercise ST segment
#                             -- Value 1: upsloping
#                             -- Value 2: flat
#                             -- Value 3: downsloping
#       -- 12. #44 (ca)        ca: number of major vessels (0-3) colored by flourosopy
#       -- 13. #51 (thal)      thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
#       -- 14. #58 (num)       (the predicted attribute)
#       num: diagnosis of heart disease (angiographic disease status)
#         -- Value 0: < 50% diameter narrowing
#         -- Value 1: > 50% diameter narrowing
#         (in any major vessel: attributes 59 through 68 are vessels)
#
# 10. Class Distribution:
#         Database:      0   1   2   3   4 Total
#           Cleveland: 164  55  36  35  13   303
#           Hungarian: 188  37  26  28  15   294
#         Switzerland:   8  48  32  30   5   123
#       Long Beach VA:  51  56  41  42  10   200

# %%
clev_df['num'].value_counts()
# Out:
# 0    164
# 1     55
# 2     36
# 3     35
# 4     13
# Name: num, dtype: int64

# %%
clev_df['clas'] = clev_df['num']
clev_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0        2
# 1     67    1   4       160   286    0        2      108      1        2
# 2     67    1   4       120   229    0        2      129      1        3
# 3     37    1   3       130   250    0        0      187      0        4
# 4     41    0   2       130   204    0        2      172      0        1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0        1
# 299   68    1   4       144   193    1        0      141      0        3
# 300   57    1   4       130   131    0        0      115      1        1
# 301   57    0   2       130   236    0        2      174      0        0
# 302   38    1   3       138   175    0        0      173      0        0
#
#      slope  ca  thal  num  loc  clas
# 0        3   0     6    0    2     0
# 1        2   3     3    2    2     2
# 2        2   2     7    1    2     1
# 3        3   0     3    0    2     0
# 4        1   0     3    0    2     0
# ..     ...  ..   ...  ...  ...   ...
# 298      2   0     7    1    2     1
# 299      2   2     7    2    2     2
# 300      2   1     7    3    2     3
# 301      2   1     3    1    2     1
# 302      1 NaN     3    0    2     0
#
# [303 rows x 16 columns]

# %%
clev_df['num'].value_counts()
# Out:
# 0    164
# 1     55
# 2     36
# 3     35
# 4     13
# Name: num, dtype: int64

# %%
clev_df['num'] = np.where(clev_df['num'] > 0, 1, clev_df['num'])
clev_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0        2
# 1     67    1   4       160   286    0        2      108      1        2
# 2     67    1   4       120   229    0        2      129      1        3
# 3     37    1   3       130   250    0        0      187      0        4
# 4     41    0   2       130   204    0        2      172      0        1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0        1
# 299   68    1   4       144   193    1        0      141      0        3
# 300   57    1   4       130   131    0        0      115      1        1
# 301   57    0   2       130   236    0        2      174      0        0
# 302   38    1   3       138   175    0        0      173      0        0
#
#      slope  ca  thal  num  loc  clas
# 0        3   0     6    0    2     0
# 1        2   3     3    1    2     2
# 2        2   2     7    1    2     1
# 3        3   0     3    0    2     0
# 4        1   0     3    0    2     0
# ..     ...  ..   ...  ...  ...   ...
# 298      2   0     7    1    2     1
# 299      2   2     7    1    2     2
# 300      2   1     7    1    2     3
# 301      2   1     3    1    2     1
# 302      1 NaN     3    0    2     0
#
# [303 rows x 16 columns]

# %%
pd.crosstab(clev_df['num'], clev_df['clas'])
# Out:
# clas    0   1   2   3   4
# num
# 0     164   0   0   0   0
# 1       0  55  36  35  13

# %%
cal_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   4       140   260    0        1      112      1        3
# 1     44    1   4       130   209    0        1      127      0        0
# 2     60    1   4       132   218    0        1      140      1        2
# 3     55    1   4       142   228    0        1      149      1        2
# 4     66    1   3       110   213    1        2       99      1        1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 195   54    0   4       127   333    1        1      154      0        0
# 196   62    1   1       NaN   139    0        1      NaN    NaN      NaN
# 197   55    1   4       122   223    1        1      100      0        0
# 198   58    1   4       NaN   385    1        2      NaN    NaN      NaN
# 199   62    1   2       120   254    0        2       93      1        0
#
#      slope  ca  thal  num  loc
# 0        2 NaN   NaN    2    1
# 1      NaN NaN   NaN    0    1
# 2        3 NaN   NaN    2    1
# 3        1 NaN   NaN    1    1
# 4        2 NaN   NaN    0    1
# ..     ...  ..   ...  ...  ...
# 195    NaN NaN   NaN    1    1
# 196    NaN NaN   NaN    0    1
# 197    NaN NaN     6    2    1
# 198    NaN NaN   NaN    0    1
# 199    NaN NaN   NaN    1    1
#
# [200 rows x 15 columns]

# %%
cal_df.describe()
# Out:
#        age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# count  200  200 200       144   193  193      200      147    147      144
# mean    59    1   4       134   179    0        1      123      1        1
# std      8    0   1        22   114    0        1       22      0        1
# min     35    0   1         0     0    0        0       69      0       -0
# 25%     55    1   3       120     0    0        0      109      0        0
# 50%     60    1   4       130   216    0        1      120      1        2
# 75%     64    1   4       147   258    1        1      140      1        2
# max     77    1   4       190   458    1        2      180      1        4
#
#        slope  ca  thal  num  loc
# count     98   2    34  200  200
# mean       2   0     6    2    1
# std        1   0     1    1    0
# min        1   0     3    0    1
# 25%        2   0     6    0    1
# 50%        2   0     7    1    1
# 75%        3   0     7    3    1
# max        3   0     7    4    1

# %% [raw]
# 10. Class Distribution:
#         Database:      0   1   2   3   4 Total
#           Cleveland: 164  55  36  35  13   303
#           Hungarian: 188  37  26  28  15   294
#         Switzerland:   8  48  32  30   5   123
#       Long Beach VA:  51  56  41  42  10   200

# %%
cal_df['num'].value_counts()
# Out:
# 1    56
# 0    51
# 3    42
# 2    41
# 4    10
# Name: num, dtype: int64

# %%
cal_df['clas'] = cal_df['num']
cal_df['num'] = np.where(cal_df['num'] > 0, 1, cal_df['num'])
cal_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   4       140   260    0        1      112      1        3
# 1     44    1   4       130   209    0        1      127      0        0
# 2     60    1   4       132   218    0        1      140      1        2
# 3     55    1   4       142   228    0        1      149      1        2
# 4     66    1   3       110   213    1        2       99      1        1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 195   54    0   4       127   333    1        1      154      0        0
# 196   62    1   1       NaN   139    0        1      NaN    NaN      NaN
# 197   55    1   4       122   223    1        1      100      0        0
# 198   58    1   4       NaN   385    1        2      NaN    NaN      NaN
# 199   62    1   2       120   254    0        2       93      1        0
#
#      slope  ca  thal  num  loc  clas
# 0        2 NaN   NaN    1    1     2
# 1      NaN NaN   NaN    0    1     0
# 2        3 NaN   NaN    1    1     2
# 3        1 NaN   NaN    1    1     1
# 4        2 NaN   NaN    0    1     0
# ..     ...  ..   ...  ...  ...   ...
# 195    NaN NaN   NaN    1    1     1
# 196    NaN NaN   NaN    0    1     0
# 197    NaN NaN     6    1    1     2
# 198    NaN NaN   NaN    0    1     0
# 199    NaN NaN   NaN    1    1     1
#
# [200 rows x 16 columns]

# %%
cal_df['chol'].replace(0, np.nan, inplace=True)
cal_df['trestbps'].replace(0, np.nan, inplace=True)
cal_df.describe()
# Out:
#        age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# count  200  200 200       143   144  193      200      147    147      144
# mean    59    1   4       135   240    0        1      123      1        1
# std      8    0   1        18    53    0        1       22      0        1
# min     35    0   1        96   100    0        0       69      0       -0
# 25%     55    1   3       120   208    0        0      109      0        0
# 50%     60    1   4       130   228    0        1      120      1        2
# 75%     64    1   4       148   271    1        1      140      1        2
# max     77    1   4       190   458    1        2      180      1        4
#
#        slope  ca  thal  num  loc  clas
# count     98   2    34  200  200   200
# mean       2   0     6    1    1     2
# std        1   0     1    0    0     1
# min        1   0     3    0    1     0
# 25%        2   0     6    0    1     0
# 50%        2   0     7    1    1     1
# 75%        3   0     7    1    1     3
# max        3   0     7    1    1     4

# %%
hung_df.describe()
# Out:
#        age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# count  294  294 294       293   271  286      293      293    293      294
# mean    48    1   3       133   251    0        0      139      0        1
# std      8    0   1        18    68    0        0       24      0        1
# min     28    0   1        92    85    0        0       82      0        0
# 25%     42    0   2       120   209    0        0      122      0        0
# 50%     49    1   3       130   243    0        0      140      0        0
# 75%     54    1   4       140   282    0        0      155      1        1
# max     66    1   4       200   603    1        2      190      1        5
#
#        slope  ca  thal  num  loc
# count    104   3    28  294  294
# mean       2   0     6    0    3
# std        0   0     2    0    0
# min        1   0     3    0    3
# 25%        2   0     5    0    3
# 50%        2   0     6    0    3
# 75%        2   0     7    1    3
# max        3   0     7    1    3

# %%
hung_df['num'].value_counts()
# Out:
# 0    188
# 1    106
# Name: num, dtype: int64

# %% [raw]
# 10. Class Distribution:
#         Database:      0   1   2   3   4 Total
#           Hungarian: 188  37  26  28  15   294
#
#             37+26+28+15 = 106

# %%
hung_df['clas'] = np.nan
hung_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     28    1   2       130   132    0        2      185      0        0
# 1     29    1   2       120   243    0        0      160      0        0
# 2     29    1   2       140   NaN    0        0      170      0        0
# 3     30    0   1       170   237    0        1      170      0        0
# 4     31    0   2       100   219    0        1      150      0        0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 289   52    1   4       160   331    0        0       94      1        2
# 290   54    0   3       130   294    0        1      100      1        0
# 291   56    1   4       155   342    1        0      150      1        3
# 292   58    0   2       180   393    0        0      110      1        1
# 293   65    1   4       130   275    0        1      115      1        1
#
#      slope  ca  thal  num  loc  clas
# 0      NaN NaN   NaN    0    3   NaN
# 1      NaN NaN   NaN    0    3   NaN
# 2      NaN NaN   NaN    0    3   NaN
# 3      NaN NaN     6    0    3   NaN
# 4      NaN NaN   NaN    0    3   NaN
# ..     ...  ..   ...  ...  ...   ...
# 289    NaN NaN   NaN    1    3   NaN
# 290      2 NaN   NaN    1    3   NaN
# 291      2 NaN   NaN    1    3   NaN
# 292      2 NaN     7    1    3   NaN
# 293      2 NaN   NaN    1    3   NaN
#
# [294 rows x 16 columns]

# %%
switz_df.describe()
# Out:
#        age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# count  123  123 123       121   123   48      122      122    122      117
# mean    55    1   4       130     0    0        0      122      0        1
# std      9    0   1        23     0    0        1       26      0        1
# min     32    0   1        80     0    0        0       60      0       -3
# 25%     51    1   4       115     0    0        0      104      0        0
# 50%     56    1   4       125     0    0        0      121      0        0
# 75%     62    1   4       145     0    0        1      140      1        2
# max     74    1   4       200     0    1        2      182      1        4
#
#        slope  ca  thal  num  loc
# count    106   5    71  123  123
# mean       2   2     6    2    4
# std        1   1     2    1    0
# min        1   1     3    0    4
# 25%        1   1     3    1    4
# 50%        2   2     7    2    4
# 75%        2   2     7    3    4
# max        3   2     7    4    4

# %%
switz_df['chol'].replace(0, np.nan, inplace=True)
switz_df['clas'] = switz_df['num']
switz_df['num'] = np.where(switz_df['num'] > 0, 1, switz_df['num'])
switz_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     32    1   1        95   NaN  NaN        0      127      0        1
# 1     34    1   4       115   NaN  NaN      NaN      154      0        0
# 2     35    1   4       NaN   NaN  NaN        0      130      1      NaN
# 3     36    1   4       110   NaN  NaN        0      125      1        1
# 4     38    0   4       105   NaN  NaN        0      166      0        3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 118   70    1   4       115   NaN    0        1       92      1        0
# 119   70    1   4       140   NaN    1        0      157      1        2
# 120   72    1   3       160   NaN  NaN        2      114      0        2
# 121   73    0   3       160   NaN    0        1      121      0        0
# 122   74    1   2       145   NaN  NaN        1      123      0        1
#
#      slope  ca  thal  num  loc  clas
# 0        1 NaN   NaN    1    4     1
# 1        1 NaN   NaN    1    4     1
# 2      NaN NaN     7    1    4     3
# 3        2 NaN     6    1    4     1
# 4        1 NaN   NaN    1    4     2
# ..     ...  ..   ...  ...  ...   ...
# 118      2 NaN     7    1    4     1
# 119      2 NaN     7    1    4     3
# 120      2   2   NaN    0    4     0
# 121      1 NaN     3    1    4     1
# 122      1 NaN   NaN    1    4     1
#
# [123 rows x 16 columns]

# %%
switz_df.describe()
# Out:
#        age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# count  123  123 123       121     0   48      122      122    122      117
# mean    55    1   4       130   NaN    0        0      122      0        1
# std      9    0   1        23   NaN    0        1       26      0        1
# min     32    0   1        80   NaN    0        0       60      0       -3
# 25%     51    1   4       115   NaN    0        0      104      0        0
# 50%     56    1   4       125   NaN    0        0      121      0        0
# 75%     62    1   4       145   NaN    0        1      140      1        2
# max     74    1   4       200   NaN    1        2      182      1        4
#
#        slope  ca  thal  num  loc  clas
# count    106   5    71  123  123   123
# mean       2   2     6    1    4     2
# std        1   1     2    0    0     1
# min        1   1     3    0    4     0
# 25%        1   1     3    1    4     1
# 50%        2   2     7    1    4     2
# 75%        2   2     7    1    4     3
# max        3   2     7    1    4     4

# %%
pd.crosstab(switz_df['num'], switz_df['clas'])
# Out:
# clas  0   1   2   3  4
# num
# 0     8   0   0   0  0
# 1     0  48  32  30  5

# %%
all_df = pd.concat([cal_df, clev_df, hung_df, switz_df], ignore_index=True)
all_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   4       140   260    0        1      112      1        3
# 1     44    1   4       130   209    0        1      127      0        0
# 2     60    1   4       132   218    0        1      140      1        2
# 3     55    1   4       142   228    0        1      149      1        2
# 4     66    1   3       110   213    1        2       99      1        1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 915   70    1   4       115   NaN    0        1       92      1        0
# 916   70    1   4       140   NaN    1        0      157      1        2
# 917   72    1   3       160   NaN  NaN        2      114      0        2
# 918   73    0   3       160   NaN    0        1      121      0        0
# 919   74    1   2       145   NaN  NaN        1      123      0        1
#
#      slope  ca  thal  num  loc  clas
# 0        2 NaN   NaN    1    1     2
# 1      NaN NaN   NaN    0    1     0
# 2        3 NaN   NaN    1    1     2
# 3        1 NaN   NaN    1    1     1
# 4        2 NaN   NaN    0    1     0
# ..     ...  ..   ...  ...  ...   ...
# 915      2 NaN     7    1    4     1
# 916      2 NaN     7    1    4     3
# 917      2   2   NaN    0    4     0
# 918      1 NaN     3    1    4     1
# 919      1 NaN   NaN    1    4     1
#
# [920 rows x 16 columns]

# %%
all_df.describe()
# Out:
#        age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# count  920  920 920       860   718  830      918      865    865      858
# mean    54    1   3       132   247    0        1      138      0        1
# std      9    0   1        19    59    0        1       26      0        1
# min     28    0   1        80    85    0        0       60      0       -3
# 25%     47    1   3       120   210    0        0      120      0        0
# 50%     54    1   4       130   240    0        0      140      0        0
# 75%     60    1   4       140   277    0        1      157      1        2
# max     77    1   4       200   603    1        2      202      1        6
#
#        slope  ca  thal  num  loc  clas
# count    611 309   434  920  920   626
# mean       2   1     5    1    2     1
# std        1   1     2    0    1     1
# min        1   0     3    0    1     0
# 25%        1   0     3    0    2     0
# 50%        2   0     6    1    2     1
# 75%        2   1     7    1    3     2
# max        3   3     7    1    4     4

# %%
all_df.to_excel('all_python_output.xlsx')

# %%
stata.run('clear')
stata.pdataframe_to_data(all_df, True)
stata.run('sum')
# Out:
#     Variable |        Obs        Mean    Std. dev.       Min        Max
# -------------+---------------------------------------------------------
#          age |        920    53.51087    9.424685         28         77
#          sex |        920    .7891304    .4081478          0          1
#           cp |        920        3.25    .9309688          1          4
#     trestbps |        860     132.286    18.53618         80        200
#         chol |        718    246.8329    58.52706         85        603
# -------------+---------------------------------------------------------
#          fbs |        830    .1662651    .3725429          0          1
#      restecg |        918    .6045752    .8058272          0          2
#      thalach |        865    137.5457    25.92628         60        202
#        exang |        865    .3895954    .4879406          0          1
#      oldpeak |        858    .8787879    1.091226       -2.6        6.2
# -------------+---------------------------------------------------------
#        slope |        611    1.770867    .6192558          1          3
#           ca |        309    .6763754     .935653          0          3
#         thal |        434    5.087558    1.919075          3          7
#          num |        920    .5532609    .4974256          0          1
#          loc |        920    2.369565    .9675631          1          4
# -------------+---------------------------------------------------------
#         clas |        626     1.29393    1.238009          0          4

# %%
stata.run('''
label define loc 1"California" 2"Cleveland" 3"Hungary" 4"Switzerland"
label values loc loc
label define cp 1"Typical angina" 2"atypical angina" 3"Non-anginal pain" 4"asymptomatic" 0"asymptomatic", replace
replace cp=0 if cp==4
label values cp cp
label define sex 0"Female" 1"Male"
label values sex sex
label define fbs 0"Normal" 1"High"
label values fbs fbs
label define restecg 0"Normal" 1"ST-T wave abnorm" 2"LVH"
label values restecg restecg
label define slope 1"upsloping" 2"flat" 3"downsloping"
label values slope slope
label define thal 3"Normal" 6"Fixed defect" 7"Reversable defect"
label values thal thal
label define num 0"No heart disease" 1"Heart disease"
label values num num
label define exang 0"Absent" 1"Present"
label values exang exang
''',)
# Out:
# .
# . label define loc 1"California" 2"Cleveland" 3"Hungary" 4"Switzerland"
#
# . label values loc loc
#
# . label define cp 1"Typical angina" 2"atypical angina" 3"Non-anginal pain" 4"as
# > ymptomatic" 0"asymptomatic", replace
#
# . replace cp=0 if cp==4
# (496 real changes made)
#
# . label values cp cp
#
# . label define sex 0"Female" 1"Male"
#
# . label values sex sex
#
# . label define fbs 0"Normal" 1"High"
#
# . label values fbs fbs
#
# . label define restecg 0"Normal" 1"ST-T wave abnorm" 2"LVH"
#
# . label values restecg restecg
#
# . label define slope 1"upsloping" 2"flat" 3"downsloping"
#
# . label values slope slope
#
# . label define thal 3"Normal" 6"Fixed defect" 7"Reversable defect"
#
# . label values thal thal
#
# . label define num 0"No heart disease" 1"Heart disease"
#
# . label values num num
#
# . label define exang 0"Absent" 1"Present"
#
# . label values exang exang
#
# .

# %%
stata.run("melogit num age chol i.sex i.cp trestbps i.restecg i.exang||loc:, or") 
#odds ratios reported for presence of heart disease dependent variable
# i. forces stata to process as categorical data
# reference groups sex = female, cp = asymptomatic, restecg = normal, exang = none
# Out:
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood =  -297.9934
# Iteration 1:   log likelihood = -293.51154
# Iteration 2:   log likelihood = -293.49378
# Iteration 3:   log likelihood = -293.49377
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -297.97346
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -297.97346  (not concave)
# Iteration 1:   log likelihood = -296.94344  (not concave)
# Iteration 2:   log likelihood = -295.91329  (not concave)
# Iteration 3:   log likelihood = -294.69263  (not concave)
# Iteration 4:   log likelihood = -294.08168  (not concave)
# Iteration 5:   log likelihood = -293.80776  (not concave)
# Iteration 6:   log likelihood = -293.56304  (not concave)
# Iteration 7:   log likelihood = -293.51293  (not concave)
# Iteration 8:   log likelihood = -293.50286  (not concave)
# Iteration 9:   log likelihood = -293.50084  (not concave)
# Iteration 10:  log likelihood = -293.50003  (not concave)
# Iteration 11:  log likelihood = -293.49987  (not concave)
# Iteration 12:  log likelihood = -293.49974  (not concave)
# Iteration 13:  log likelihood = -293.49973  (not concave)
# Iteration 14:  log likelihood = -293.49973  (not concave)
# Iteration 15:  log likelihood = -293.49972  (not concave)
# Iteration 16:  log likelihood = -293.49972  (not concave)
# Iteration 17:  log likelihood = -293.49972  (not concave)
# Iteration 18:  log likelihood = -293.49972  (not concave)
# Iteration 19:  log likelihood = -293.49972  (not concave)
# Iteration 20:  log likelihood = -293.49972  (not concave)
# Iteration 21:  log likelihood = -293.49972  (not concave)
# Iteration 22:  log likelihood = -293.49972  (not concave)
# Iteration 23:  log likelihood = -293.49972  (not concave)
# Iteration 24:  log likelihood = -293.49972  (not concave)
# Iteration 25:  log likelihood = -293.49972  (backed up)
# Iteration 26:  log likelihood = -293.49972  (not concave)
# Iteration 27:  log likelihood = -293.49972  (backed up)
# Iteration 28:  log likelihood = -293.49972  (backed up)
# Iteration 29:  log likelihood = -293.49972  (backed up)
# Iteration 30:  log likelihood = -293.49972  (not concave)
# Iteration 31:  log likelihood = -293.49972  (not concave)
# Iteration 32:  log likelihood = -293.49972  (backed up)
# Iteration 33:  log likelihood = -293.49972  (backed up)
# Iteration 34:  log likelihood = -293.49972  (not concave)
# Iteration 35:  log likelihood = -293.49972  (not concave)
# Iteration 36:  log likelihood = -293.49972  (not concave)
# Iteration 37:  log likelihood = -293.49972  (backed up)
# Iteration 38:  log likelihood = -293.49972  (backed up)
# Iteration 39:  log likelihood = -293.49972  (not concave)
# Iteration 40:  log likelihood = -293.49972  (not concave)
# Iteration 41:  log likelihood = -293.49972
# Iteration 42:  log likelihood = -293.49972  (not concave)
# Iteration 43:  log likelihood = -293.49972
# Iteration 44:  log likelihood = -293.49971  (backed up)
# Iteration 45:  log likelihood = -293.49962  (not concave)
# Iteration 46:  log likelihood = -293.49962
# Iteration 47:  log likelihood = -293.49953  (not concave)
# Iteration 48:  log likelihood = -293.49951  (not concave)
# Iteration 49:  log likelihood = -293.49948  (not concave)
# Iteration 50:  log likelihood = -293.49946
# Iteration 51:  log likelihood = -293.49945  (backed up)
# Iteration 52:  log likelihood = -293.49876
# Iteration 53:  log likelihood = -293.49377
# Iteration 54:  log likelihood = -293.49377
#
# Mixed-effects logistic regression               Number of obs     =        674
# Group variable: loc                             Number of groups  =          3
#
#                                                 Obs per group:
#                                                               min =        102
#                                                               avg =      224.7
#                                                               max =        303
#
# Integration method: mvaghermite                 Integration pts.  =          7
#
#                                                 Wald chi2(10)     =     191.17
# Log likelihood = -293.49377                     Prob > chi2       =     0.0000
# ------------------------------------------------------------------------------
#          num | Odds ratio   Std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#          age |   1.044202    .012758     3.54   0.000     1.019494     1.06951
#         chol |   1.003965   .0017925     2.22   0.027     1.000458    1.007484
#              |
#          sex |
#        Male  |   4.568875   1.198277     5.79   0.000      2.73253      7.6393
#              |
#           cp |
# Typical a..  |    .303934   .1281371    -2.82   0.005       .13302     .694451
# atypical ..  |   .1110789   .0335259    -7.28   0.000     .0614782    .2006976
# Non-angin..  |   .1957112   .0512487    -6.23   0.000     .1171442    .3269719
#              |
#     trestbps |   1.012473   .0061871     2.03   0.043     1.000419    1.024672
#              |
#      restecg |
# ST-T wave..  |   1.203066   .3901334     0.57   0.569     .6371764    2.271534
#         LVH  |   1.322985   .3274602     1.13   0.258     .8144583    2.149023
#              |
#        exang |
#     Present  |   4.609933   1.040398     6.77   0.000     2.962035    7.174621
#        _cons |    .002529   .0026725    -5.66   0.000     .0003188    .0200653
# -------------+----------------------------------------------------------------
# loc          |
#    var(_cons)|   4.44e-34   2.98e-18                             .           .
# ------------------------------------------------------------------------------
# Note: Estimates are transformed only in the first equation to odds ratios.
# Note: _cons estimates baseline odds (conditional on zero random effects).
# LR test vs. logistic model: chi2(0) = 0.00                Prob > chi2 =      .
#
# Note: LR test is conservative and provided only for reference.

# %%
# %%stata
# tab cp num, row
# Out:
# +----------------+
# | Key            |
# |----------------|
# |   frequency    |
# | row percentage |
# +----------------+
#
#                  |          num
#               cp | No heart   Heart dis |     Total
# -----------------+----------------------+----------
#     asymptomatic |       104        392 |       496
#                  |     20.97      79.03 |    100.00
# -----------------+----------------------+----------
#   Typical angina |        26         20 |        46
#                  |     56.52      43.48 |    100.00
# -----------------+----------------------+----------
#  atypical angina |       150         24 |       174
#                  |     86.21      13.79 |    100.00
# -----------------+----------------------+----------
# Non-anginal pain |       131         73 |       204
#                  |     64.22      35.78 |    100.00
# -----------------+----------------------+----------
#            Total |       411        509 |       920
#                  |     44.67      55.33 |    100.00

# %%
all_df['cp'].value_counts()
# Out:
# 4    496
# 3    204
# 2    174
# 1     46
# Name: cp, dtype: int64

# %%
pd.crosstab(all_df['cp'], all_df['num'])
# Out:
# num    0    1
# cp
# 1     26   20
# 2    150   24
# 3    131   73
# 4    104  392

# %%
engine = sqlalchemy.create_engine('sqlite:///final_project.db')

# %%
# %load_ext sql
# %sql sqlite:///final_project.db
# Out:
# 'Connected: @final_project.db'

# %%
#create database and cursor
conn = sqlite3.connect("final_project.db")
c = conn.cursor()
c.execute("DROP TABLE IF EXISTS all_table");
conn.commit()

# %%
# %%sql
# DROP TABLE IF EXISTS all_table;
# CREATE TABLE all_table (
#     ID INTEGER NOT NULL PRIMARY KEY,
#     age INTERGER CHECK (age >=18 AND age < 120),
#     sex INTERGER CHECK (sex >= 0 AND sex <=1),
#     cp INTERGER CHECK (cp >= 1 AND cp <=4),
#     trestbps INTERGER CHECK (trestbps >50 AND trestbps <300),
#     chol INTERGER CHECK (chol >0),
#     fbs INTERGER CHECK (fbs >= 0 AND fbs <=1),
#     restecg INTERGER CHECK (restecg >= 0 AND restecg <=2),
#     thalach INTERGER CHECK (thalach >30),
#     exang INTERGER CHECK (exang >= 0 AND exang <=1),
#     oldpeak REAL,
#     slope INTERGER CHECK (slope >= 1 AND slope <=3),
#     ca INTERGER CHECK (ca >= 0 AND ca <=3),
#     thal INTERGER CHECK (thal >= 3 AND thal <=7),
#     num INTERGER CHECK (num >= 0 AND num <=1),
#     loc INTERGER CHECK (loc >= 1 AND loc <=4),
#     clas INTERGER CHECK (clas >= 0 AND clas <=4)
# );
# Out:
#  * sqlite:///final_project.db
# Done.
# Done.
# []

# %%
# %%sql
# SELECT * FROM all_table;
# Out:
#  * sqlite:///final_project.db
# Done.
# []

# %%
pd.read_sql('all_table', engine)
# Out:
# Empty DataFrame
# Columns: [ID, age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, num, loc, clas]
# Index: []

# %%
all_df.to_sql('all_table', engine, if_exists='append', index=False)
# Out:
# 920

# %%
pd.read_sql('all_table', engine)
# Out:
#       ID  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      1   63    1   4       140   260    0        1      112      1        3
# 1      2   44    1   4       130   209    0        1      127      0        0
# 2      3   60    1   4       132   218    0        1      140      1        2
# 3      4   55    1   4       142   228    0        1      149      1        2
# 4      5   66    1   3       110   213    1        2       99      1        1
# ..   ...  ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 915  916   70    1   4       115   NaN    0        1       92      1        0
# 916  917   70    1   4       140   NaN    1        0      157      1        2
# 917  918   72    1   3       160   NaN  NaN        2      114      0        2
# 918  919   73    0   3       160   NaN    0        1      121      0        0
# 919  920   74    1   2       145   NaN  NaN        1      123      0        1
#
#      slope  ca  thal  num  loc  clas
# 0        2 NaN   NaN    1    1     2
# 1      NaN NaN   NaN    0    1     0
# 2        3 NaN   NaN    1    1     2
# 3        1 NaN   NaN    1    1     1
# 4        2 NaN   NaN    0    1     0
# ..     ...  ..   ...  ...  ...   ...
# 915      2 NaN     7    1    4     1
# 916      2 NaN     7    1    4     3
# 917      2   2   NaN    0    4     0
# 918      1 NaN     3    1    4     1
# 919      1 NaN   NaN    1    4     1
#
# [920 rows x 17 columns]

# %%
all_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   4       140   260    0        1      112      1        3
# 1     44    1   4       130   209    0        1      127      0        0
# 2     60    1   4       132   218    0        1      140      1        2
# 3     55    1   4       142   228    0        1      149      1        2
# 4     66    1   3       110   213    1        2       99      1        1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 915   70    1   4       115   NaN    0        1       92      1        0
# 916   70    1   4       140   NaN    1        0      157      1        2
# 917   72    1   3       160   NaN  NaN        2      114      0        2
# 918   73    0   3       160   NaN    0        1      121      0        0
# 919   74    1   2       145   NaN  NaN        1      123      0        1
#
#      slope  ca  thal  num  loc  clas
# 0        2 NaN   NaN    1    1     2
# 1      NaN NaN   NaN    0    1     0
# 2        3 NaN   NaN    1    1     2
# 3        1 NaN   NaN    1    1     1
# 4        2 NaN   NaN    0    1     0
# ..     ...  ..   ...  ...  ...   ...
# 915      2 NaN     7    1    4     1
# 916      2 NaN     7    1    4     3
# 917      2   2   NaN    0    4     0
# 918      1 NaN     3    1    4     1
# 919      1 NaN   NaN    1    4     1
#
# [920 rows x 16 columns]

# %%
# %%sql
# DROP TABLE IF EXISTS sex_table;
# CREATE TABLE sex_table (
#     sex_id INTEGER NOT NULL PRIMARY KEY,
#     sex_text TEXT,
#     FOREIGN KEY(sex_id) REFERENCES all_table (sex)
# );
# Out:
#  * sqlite:///final_project.db
# Done.
# Done.
# []

# %%
c.execute("INSERT INTO sex_table (sex_id, sex_text) VALUES(0, 'Female')")
c.execute("INSERT INTO sex_table (sex_id, sex_text) VALUES(1, 'Male')")
conn.commit()
conn.close
# Out:
# <function Connection.close>

# %%
# %%sql
# SELECT * FROM sex_table
# Out:
#  * sqlite:///final_project.db
# Done.
# [(0, 'Female'), (1, 'Male')]

# %%
# %%sql
# SELECT age, chol, sex FROM all_table
# WHERE all_table.ID=2
# Out:
#  * sqlite:///final_project.db
# Done.
# [(44, 209, 1)]

# %%
# %%sql
# SELECT age, chol, sex_text FROM all_table
# INNER JOIN sex_table ON sex_table.sex_id = all_table.sex
# WHERE all_table.ID = 2
# Out:
#  * sqlite:///final_project.db
# Done.
# [(44, 209, 'Male')]

# %%
# %%sql
# SELECT age, chol, sex FROM all_table
# WHERE all_table.ID=919
# Out:
#  * sqlite:///final_project.db
# Done.
# [(73, None, 0)]

# %%
# %%sql
# SELECT age, chol, sex_text FROM all_table
# INNER JOIN sex_table ON sex_table.sex = all_table.sex
# WHERE all_table.ID = 919
# Out:
#  * sqlite:///final_project.db
# (sqlite3.OperationalError) no such column: sex_table.sex
# [SQL: SELECT age, chol, sex_text FROM all_table
# INNER JOIN sex_table ON sex_table.sex = all_table.sex
# WHERE all_table.ID = 919]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
# %%sql
# DROP TABLE IF EXISTS loc_table;
# CREATE TABLE loc_table (
#     loc_id INTEGER NOT NULL PRIMARY KEY,
#     location TEXT,
#     FOREIGN KEY(loc_id) REFERENCES all_table (loc)
# );
# Out:
#  * sqlite:///final_project.db
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO loc_table (loc_id, location) VALUES(1, 'Calfornia');
# INSERT INTO loc_table (loc_id, location) VALUES(2, 'Cleveland');
# INSERT INTO loc_table (loc_id, location) VALUES(3, 'Hungary');
# INSERT INTO loc_table (loc_id, location) VALUES(4, 'Switzerland');
# Out:
#  * sqlite:///final_project.db
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# []

# %%
# %%sql
# PRAGMA table_info(loc_table);
# Out:
#  * sqlite:///final_project.db
# Done.
# [(0, 'loc_id', 'INTEGER', 1, None, 1), (1, 'location', 'TEXT', 0, None, 0)]

# %%
# %%sql
# SELECT * FROM loc_table
# Out:
#  * sqlite:///final_project.db
# Done.
# [(1, 'Calfornia'), (2, 'Cleveland'), (3, 'Hungary'), (4, 'Switzerland')]

# %%
# %%sql
# PRAGMA table_info(all_table);
# Out:
#  * sqlite:///final_project.db
# Done.
# [(0, 'ID', 'INTEGER', 1, None, 1),
#  (1, 'age', 'INTERGER', 0, None, 0),
#  (2, 'sex', 'INTERGER', 0, None, 0),
#  (3, 'cp', 'INTERGER', 0, None, 0),
#  (4, 'trestbps', 'INTERGER', 0, None, 0),
#  (5, 'chol', 'INTERGER', 0, None, 0),
#  (6, 'fbs', 'INTERGER', 0, None, 0),
#  (7, 'restecg', 'INTERGER', 0, None, 0),
#  (8, 'thalach', 'INTERGER', 0, None, 0),
#  (9, 'exang', 'INTERGER', 0, None, 0),
#  (10, 'oldpeak', 'REAL', 0, None, 0),
#  (11, 'slope', 'INTERGER', 0, None, 0),
#  (12, 'ca', 'INTERGER', 0, None, 0),
#  (13, 'thal', 'INTERGER', 0, None, 0),
#  (14, 'num', 'INTERGER', 0, None, 0),
#  (15, 'loc', 'INTERGER', 0, None, 0),
#  (16, 'clas', 'INTERGER', 0, None, 0)]

# %%
import seaborn as sns
sns.regplot(x=all_df['age'], y=all_df['chol'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
# %%stata
# regress chol age
# Out:
#       Source |       SS           df       MS      Number of obs   =       718
# -------------+----------------------------------   F(1, 716)       =      5.01
#        Model |    17052.75         1    17052.75   Prob > F        =    0.0256
#     Residual |  2438971.19       716  3406.38435   R-squared       =    0.0069
# -------------+----------------------------------   Adj R-squared   =    0.0056
#        Total |  2456023.94       717  3425.41694   Root MSE        =    58.364
#
# ------------------------------------------------------------------------------
#         chol | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#          age |   .5154798   .2303888     2.24   0.026     .0631616    .9677981
#        _cons |   219.5412   12.39072    17.72   0.000     195.2147    243.8676
# ------------------------------------------------------------------------------

# %%
# %stata logit num chol
# Out:
# Iteration 0:   log likelihood = -497.20882
# Iteration 1:   log likelihood = -492.11506
# Iteration 2:   log likelihood = -492.11085
# Iteration 3:   log likelihood = -492.11085
#
# Logistic regression                                     Number of obs =    718
#                                                         LR chi2(1)    =  10.20
#                                                         Prob > chi2   = 0.0014
# Log likelihood = -492.11085                             Pseudo R2     = 0.0103
#
# ------------------------------------------------------------------------------
#          num | Coefficient  Std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#         chol |   .0041715   .0013369     3.12   0.002     .0015512    .0067917
#        _cons |  -1.101728   .3378293    -3.26   0.001    -1.763861   -.4395943
# ------------------------------------------------------------------------------

# %%
stata.run("melogit num age chol i.sex i.cp trestbps i.restecg i.exang||loc:, or")
# Out:
# Fitting fixed-effects model:
#
# Iteration 0:   log likelihood =  -297.9934
# Iteration 1:   log likelihood = -293.51154
# Iteration 2:   log likelihood = -293.49378
# Iteration 3:   log likelihood = -293.49377
#
# Refining starting values:
#
# Grid node 0:   log likelihood = -297.97346
#
# Fitting full model:
#
# Iteration 0:   log likelihood = -297.97346  (not concave)
# Iteration 1:   log likelihood = -296.94344  (not concave)
# Iteration 2:   log likelihood = -295.91329  (not concave)
# Iteration 3:   log likelihood = -294.69263  (not concave)
# Iteration 4:   log likelihood = -294.08168  (not concave)
# Iteration 5:   log likelihood = -293.80776  (not concave)
# Iteration 6:   log likelihood = -293.56304  (not concave)
# Iteration 7:   log likelihood = -293.51293  (not concave)
# Iteration 8:   log likelihood = -293.50286  (not concave)
# Iteration 9:   log likelihood = -293.50084  (not concave)
# Iteration 10:  log likelihood = -293.50003  (not concave)
# Iteration 11:  log likelihood = -293.49987  (not concave)
# Iteration 12:  log likelihood = -293.49974  (not concave)
# Iteration 13:  log likelihood = -293.49973  (not concave)
# Iteration 14:  log likelihood = -293.49973  (not concave)
# Iteration 15:  log likelihood = -293.49972  (not concave)
# Iteration 16:  log likelihood = -293.49972  (not concave)
# Iteration 17:  log likelihood = -293.49972  (not concave)
# Iteration 18:  log likelihood = -293.49972  (not concave)
# Iteration 19:  log likelihood = -293.49972  (not concave)
# Iteration 20:  log likelihood = -293.49972  (not concave)
# Iteration 21:  log likelihood = -293.49972  (not concave)
# Iteration 22:  log likelihood = -293.49972  (not concave)
# Iteration 23:  log likelihood = -293.49972  (not concave)
# Iteration 24:  log likelihood = -293.49972  (not concave)
# Iteration 25:  log likelihood = -293.49972  (backed up)
# Iteration 26:  log likelihood = -293.49972  (not concave)
# Iteration 27:  log likelihood = -293.49972  (backed up)
# Iteration 28:  log likelihood = -293.49972  (backed up)
# Iteration 29:  log likelihood = -293.49972  (backed up)
# Iteration 30:  log likelihood = -293.49972  (not concave)
# Iteration 31:  log likelihood = -293.49972  (not concave)
# Iteration 32:  log likelihood = -293.49972  (backed up)
# Iteration 33:  log likelihood = -293.49972  (backed up)
# Iteration 34:  log likelihood = -293.49972  (not concave)
# Iteration 35:  log likelihood = -293.49972  (not concave)
# Iteration 36:  log likelihood = -293.49972  (not concave)
# Iteration 37:  log likelihood = -293.49972  (backed up)
# Iteration 38:  log likelihood = -293.49972  (backed up)
# Iteration 39:  log likelihood = -293.49972  (not concave)
# Iteration 40:  log likelihood = -293.49972  (not concave)
# Iteration 41:  log likelihood = -293.49972
# Iteration 42:  log likelihood = -293.49972  (not concave)
# Iteration 43:  log likelihood = -293.49972
# Iteration 44:  log likelihood = -293.49971  (backed up)
# Iteration 45:  log likelihood = -293.49962  (not concave)
# Iteration 46:  log likelihood = -293.49962
# Iteration 47:  log likelihood = -293.49953  (not concave)
# Iteration 48:  log likelihood = -293.49951  (not concave)
# Iteration 49:  log likelihood = -293.49948  (not concave)
# Iteration 50:  log likelihood = -293.49946
# Iteration 51:  log likelihood = -293.49945  (backed up)
# Iteration 52:  log likelihood = -293.49876
# Iteration 53:  log likelihood = -293.49377
# Iteration 54:  log likelihood = -293.49377
#
# Mixed-effects logistic regression               Number of obs     =        674
# Group variable: loc                             Number of groups  =          3
#
#                                                 Obs per group:
#                                                               min =        102
#                                                               avg =      224.7
#                                                               max =        303
#
# Integration method: mvaghermite                 Integration pts.  =          7
#
#                                                 Wald chi2(10)     =     191.17
# Log likelihood = -293.49377                     Prob > chi2       =     0.0000
# ------------------------------------------------------------------------------
#          num | Odds ratio   Std. err.      z    P>|z|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#          age |   1.044202    .012758     3.54   0.000     1.019494     1.06951
#         chol |   1.003965   .0017925     2.22   0.027     1.000458    1.007484
#              |
#          sex |
#        Male  |   4.568875   1.198277     5.79   0.000      2.73253      7.6393
#              |
#           cp |
# Typical a..  |    .303934   .1281371    -2.82   0.005       .13302     .694451
# atypical ..  |   .1110789   .0335259    -7.28   0.000     .0614782    .2006976
# Non-angin..  |   .1957112   .0512487    -6.23   0.000     .1171442    .3269719
#              |
#     trestbps |   1.012473   .0061871     2.03   0.043     1.000419    1.024672
#              |
#      restecg |
# ST-T wave..  |   1.203066   .3901334     0.57   0.569     .6371764    2.271534
#         LVH  |   1.322985   .3274602     1.13   0.258     .8144583    2.149023
#              |
#        exang |
#     Present  |   4.609933   1.040398     6.77   0.000     2.962035    7.174621
#        _cons |    .002529   .0026725    -5.66   0.000     .0003188    .0200653
# -------------+----------------------------------------------------------------
# loc          |
#    var(_cons)|   4.44e-34   2.98e-18                             .           .
# ------------------------------------------------------------------------------
# Note: Estimates are transformed only in the first equation to odds ratios.
# Note: _cons estimates baseline odds (conditional on zero random effects).
# LR test vs. logistic model: chi2(0) = 0.00                Prob > chi2 =      .
#
# Note: LR test is conservative and provided only for reference.

# %%
switz_df.describe()
# Out:
#        age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# count  123  123 123       121     0   48      122      122    122      117
# mean    55    1   4       130   NaN    0        0      122      0        1
# std      9    0   1        23   NaN    0        1       26      0        1
# min     32    0   1        80   NaN    0        0       60      0       -3
# 25%     51    1   4       115   NaN    0        0      104      0        0
# 50%     56    1   4       125   NaN    0        0      121      0        0
# 75%     62    1   4       145   NaN    0        1      140      1        2
# max     74    1   4       200   NaN    1        2      182      1        4
#
#        slope  ca  thal  num  loc  clas
# count    106   5    71  123  123   123
# mean       2   2     6    1    4     2
# std        1   1     2    0    0     1
# min        1   1     3    0    4     0
# 25%        1   1     3    1    4     1
# 50%        2   2     7    1    4     2
# 75%        2   2     7    1    4     3
# max        3   2     7    1    4     4

# %%
pd.crosstab(all_df['num'], all_df['sex'])
# Out:
# sex    0    1
# num
# 0    144  267
# 1     50  459

# %%
all_df['sex'].value_counts()
# Out:
# 1    726
# 0    194
# Name: sex, dtype: int64

# %%
# %%sql
# SELECT AVG(age)
# FROM all_table
# WHERE loc=3
# Out:
#  * sqlite:///final_project.db
# Done.
# [(47.826530612244895,)]

# %%
# %%sql
# SELECT AVG(age)
# FROM all_table
# Out:
#  * sqlite:///final_project.db
# Done.
# [(53.51086956521739,)]

# %%
all_df['num'].replace(0, 'Heart disease Absent', inplace=True)
all_df['num'].replace(1, 'Heart disease Present', inplace=True)
all_df['sex'].replace(0, 'Female', inplace=True)
all_df['sex'].replace(1, 'Male', inplace=True)

# %%
df = all_df['num'].groupby(all_df['sex']).value_counts()
df
# Out:
# sex     num
# Female  Heart disease Absent     144
#         Heart disease Present     50
# Male    Heart disease Present    459
#         Heart disease Absent     267
# Name: num, dtype: int64

# %%
plot = df.plot.pie(y='num', figsize=(5,5), fontsize=14, rotatelabels=False)
plt.title('Pie chart show distribution of sex and heart disease', weight='bold', size=14)
plt.ylabel("")
plt.show()

# %%
# %%stata
# tab chol if loc ==4
# Out:
# no observations

# %%
pd.options.display.float_format = "{:,.0f}".format

# %%
#%%sql
#SELECT * FROM all_table
